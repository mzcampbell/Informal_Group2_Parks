# %%
# Dependencies
import requests
import json
import pandas as pd

from api_keys import url_visit_center

# %%
# Performing a GET Request and saving the 
# API's response within a variable
url = url_visit_center
response = requests.get(url)
response_json = response.json()
print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "addresses": [
#                 {
#                     "city": "Mountainair",
#                     "line1": "Ab\u00f3 Visitor Center",
#                     "line2": "Salinas Pueblo Missions NM",
#                     "line3": "#69 Abo Ruins Road",
#                     "postalCode": "87036",
#                     "stateCode": "NM",
#                     "type": "Physical"
#                 },
#                 {
#                     "city": "Mountainair",
#                     "line1": "Ab\u00f3 Visitor Center",
#                     "line2": "Salinas Pueblo Missions NM",
#                     "line3": "PO Box 517",
#                     "postalCode": "87036",
#                     "stateCode": "NM",
#                     "type": "Mailing"
#                 }
#             ],
#             "amenities": [
#                 "Automated External Defibrillator (AED)",
#                 "Benches/Seating",
#                 "Braille",
# ...
